# %% [markdown]
#    # Import Dependencies

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
from sqlalchemy import create_engine

# %% [markdown]
# # Import datasets and create dataframes

# %%
# Reading the poverty and income csv file and creating a dataframe
income_csv_file ="2018_poverty_income.csv"
income_df = pd.read_csv(income_csv_file, encoding = "UTF-8")
income_df.rename(columns={'County Name': 'County'}, inplace=True)

#income_df

# %%
# Reading the crime csv file and creating a dataframe
crime_csv_file ="crime_data.csv"
crime_df = pd.read_csv(crime_csv_file, encoding = "UTF-8")

# crime_df = all_crime_df.drop(columns=["Unnamed: 11", "Unnamed: 12", "Unnamed: 13", "Unnamed: 14", "Unnamed: 15", "Unnamed: 16", "Unnamed: 17", "Unnamed: 18"])

crime_df.rename(columns={'Violent\ncrime': 'Violent_Crime',
                         "Property\ncrime": "Property_Crime",
                         "Total Crime": "Total_Crime"
                        }, inplace=True)

# crime_df["Property_Crime"] = crime_df["Property_Crime"].astype(float)

# crime_df["Total_Crimes"]= int(crime_df["Violent_Crime"]) + int(crime_df["Property_Crime"])
# crime_df["Property_Crime"].fillna(value=0)

# crime_df["Property_Crime"] = crime_df['Property_Crime'].str.rstrip(",").astype("float")
# crime_df["Property_Crime"].fillna(value=0)

#crime_df = crime_df.drop(columns=["Violent_Crime", "Property_Crime"])
crime_df
# Out:
#               County  Violent_Crime Property_Crime  Total_Crime
# 0    Anderson County           54.0            350          404
# 1     Andrews County           17.0             80           97
# 2    Angelina County           96.0            492          588
# 3     Aransas County           76.0            264          340
# 4    Atascosa County           83.0            520          603
# ..               ...            ...            ...          ...
# 222      Wood County           73.0            201          274
# 223    Yoakum County            5.0             30           35
# 224     Young County            8.0             39           47
# 225    Zapata County            7.0            202          209
# 226    Zavala County            6.0             38           44
#
# [227 rows x 4 columns]

# %%
# Reading the population csv file and creating a dataframe
population_csv_file ="population.csv"
population_df = pd.read_csv(population_csv_file, encoding = "UTF-8")

#population_df

# %%
# Reading the crime csv file and creating a dataframe
unemployment_csv_file ="Unemployment rate.csv"
unemployment_df = pd.read_csv(unemployment_csv_file, encoding = "UTF-8")
unemployment_df.rename(columns={'County Name': 'County'}, inplace=True)

#unemployment_df

# %% [markdown]
# # Merge data

# %%
merge_df = income_df.merge(population_df, on = "County").merge(unemployment_df, on = "County")

complete_df = merge_df.merge(crime_df, how = "left", on = "County")

complete_df.rename(columns = {
    "Poverty Estimate": "Poverty_Estimate",
    "Poverty Percent": "Poverty_Percent",
    "Median Household Income": "Median_Household_Income",
    "Unemployment Rate (%)": "Unemployment_Rate",
}, inplace = True)

complete_df
# Out:
#               County  Poverty_Estimate  Poverty_Percent  \
# 0    Anderson County              8778             19.8
# 1     Andrews County              1922             10.7
# 2    Angelina County             15052             17.9
# 3     Aransas County              4642             19.9
# 4      Archer County               922             10.6
# ..               ...               ...              ...
# 249      Wood County              6625             15.3
# 250    Yoakum County              1028             12.1
# 251     Young County              2468             13.9
# 252    Zapata County              4529             32.1
# 253    Zavala County              3701             32.0
#
#      Median_Household_Income  Population  Unemployment_Rate  Violent_Crime  \
# 0                      45969       57735                3.1           54.0
# 1                      84946       18705                2.4           17.0
# 2                      46653       86715                4.3           96.0
# 3                      46912       23510                5.9           76.0
# 4                      61190        8553                3.0            NaN
# ..                       ...         ...                ...            ...
# 249                    48384       45539                4.2           73.0
# 250                    61560        8713                2.9            5.0
# 251                    49301       18010                3.2            8.0
# 252                    33160       14179                5.5            7.0
# 253                    30076       11840                9.6            6.0
#
#     Property_Crime  Total_Crime
# 0              350        404.0
# 1               80         97.0
# 2              492        588.0
# 3              264        340.0
# 4              NaN          NaN
# ..             ...          ...
# 249            201        274.0
# 250             30         35.0
# 251             39         47.0
# 252            202        209.0
# 253             38         44.0
#
# [254 rows x 9 columns]

# %% [markdown]
# # Output a combined csv file

# %%
complete_df.to_csv('complete.csv', index=False)
