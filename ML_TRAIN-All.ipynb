# %%
import pandas as pd
import numpy as np
from pprint import pprint
from sqlalchemy import create_engine
from keys import sqlkey

# %%
#CREATE DATABASE CONNECTION
engine = create_engine('postgresql://postgres:'+sqlkey+'@localhost:5432/horse_races')
connection = engine.connect()

# %%
data_df = pd.read_sql(sql='select * from raceruns',con=connection)

# %%
connection.close()

# %%
data_df
# Out:
#        race_id  won  race_no  surface distance  race_class  sec_time1  \
# 0            0    0        1        0     1400           5      13.53
# 1            0    0        1        0     1400           5      13.53
# 2            0    0        1        0     1400           5      13.53
# 3            0    0        1        0     1400           5      13.53
# 4            0    0        1        0     1400           5      13.53
# ...        ...  ...      ...      ...      ...         ...        ...
# 79442     6348    0       10        0     1600           2      25.46
# 79443     6348    0       10        0     1600           2      25.46
# 79444     6348    0       10        0     1600           2      25.46
# 79445     6348    0       10        0     1600           2      25.46
# 79446     6348    0       10        0     1600           2      25.46
#
#        sec_time2  sec_time3  sec_time4  ...  behind_sec4  time1  time2  time3  \
# 0          21.59      23.94      23.58  ...         8.00  13.85  21.59  23.86
# 1          21.59      23.94      23.58  ...         5.75  14.57  21.99  23.30
# 2          21.59      23.94      23.58  ...         4.75  13.69  21.59  23.90
# 3          21.59      23.94      23.58  ...         6.25  14.09  21.83  23.70
# 4          21.59      23.94      23.58  ...         3.75  14.77  21.75  23.22
# ...          ...        ...        ...  ...          ...    ...    ...    ...
# 79442      24.06      23.73      22.71  ...         1.25  26.14  23.98  23.53
# 79443      24.06      23.73      22.71  ...         2.25  25.82  24.10  23.77
# 79444      24.06      23.73      22.71  ...         3.00  26.58  24.06  23.37
# 79445      24.06      23.73      22.71  ...         2.50  26.58  24.02  23.45
# 79446      24.06      23.73      22.71  ...         4.25  25.70  24.06  23.77
#
#        time4  finish_time  win_odds  place_odds  trainer_id  jockey_id
# 0      24.62        83.92       9.7         3.7         118          2
# 1      23.70        83.56      16.0         4.9         164         57
# 2      24.22        83.40       3.5         1.5         137         18
# 3      24.00        83.62      39.0        11.0          80         59
# 4      23.50        83.24      50.0        14.0           9        154
# ...      ...          ...       ...         ...         ...        ...
# 79442  22.52        96.17      99.0         NaN          73         40
# 79443  22.61        96.30      99.0         NaN         164         63
# 79444  22.43        96.44      99.0         NaN         111         68
# 79445  22.29        96.34       4.6         NaN         118         95
# 79446  23.10        96.63      99.0         NaN          27          4
#
# [79447 rows x 48 columns]

# %%
data_df = data_df.dropna()

# %%
data_df
# Out:
#        race_id  won  race_no  surface distance  race_class  sec_time1  \
# 0            0    0        1        0     1400           5      13.53
# 1            0    0        1        0     1400           5      13.53
# 2            0    0        1        0     1400           5      13.53
# 3            0    0        1        0     1400           5      13.53
# 4            0    0        1        0     1400           5      13.53
# ...        ...  ...      ...      ...      ...         ...        ...
# 76706     6128    0       10        0     1400           3      13.34
# 76707     6128    0       10        0     1400           3      13.34
# 76708     6128    0       10        0     1400           3      13.34
# 76709     6128    0       10        0     1400           3      13.34
# 76710     6128    0       10        0     1400           3      13.34
#
#        sec_time2  sec_time3  sec_time4  ...  behind_sec4  time1  time2  time3  \
# 0          21.59      23.94      23.58  ...         8.00  13.85  21.59  23.86
# 1          21.59      23.94      23.58  ...         5.75  14.57  21.99  23.30
# 2          21.59      23.94      23.58  ...         4.75  13.69  21.59  23.90
# 3          21.59      23.94      23.58  ...         6.25  14.09  21.83  23.70
# 4          21.59      23.94      23.58  ...         3.75  14.77  21.75  23.22
# ...          ...        ...        ...  ...          ...    ...    ...    ...
# 76706      21.79      24.09      22.32  ...         8.25  13.46  22.03  23.97
# 76707      21.79      24.09      22.32  ...         5.50  13.70  22.07  23.85
# 76708      21.79      24.09      22.32  ...         4.50  13.34  21.91  24.05
# 76709      21.79      24.09      22.32  ...         7.00  13.50  21.99  23.89
# 76710      21.79      24.09      22.32  ...         7.50  13.50  22.07  24.21
#
#        time4  finish_time  win_odds  place_odds  trainer_id  jockey_id
# 0      24.62        83.92       9.7         3.7         118          2
# 1      23.70        83.56      16.0         4.9         164         57
# 2      24.22        83.40       3.5         1.5         137         18
# 3      24.00        83.62      39.0        11.0          80         59
# 4      23.50        83.24      50.0        14.0           9        154
# ...      ...          ...       ...         ...         ...        ...
# 76706  23.41        82.87      33.0         5.7         118         40
# 76707  22.80        82.42      99.0        14.0          73        161
# 76708  22.95        82.25       8.2         2.0         138         10
# 76709  23.28        82.66      59.0         9.9           7         23
# 76710  22.96        82.74      99.0        26.0          47        162
#
# [44047 rows x 48 columns]

# %%
from sklearn.model_selection import train_test_split

X = data_df.drop(columns=["won"])

y = data_df["won"]


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify = y)

# %%
X_train.head(50)

X_train.to_csv("X_train.csv")
y_train.to_csv("y_train.csv")

X_test.to_csv("X_test.csv")
y_test.to_csv("y_test.csv")

# %%
from sklearn import preprocessing 
scaler = preprocessing.MinMaxScaler()
minmax_df = scaler.fit(X_train) #something wrong here
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
horse_model = LogisticRegression(max_iter=10000)
horse_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
horse_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(f"Training Data Score: {horse_model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {horse_model.score(X_test_scaled, y_test)}")
print(f"for one single line:{horse_model.predict(X_train_scaled[12].reshape(1,-1))}")
# Out:
# Training Data Score: 0.9995762070531254
# Testing Data Score: 0.9996367598982928
# for one single line:[1]

# %%
horse_model.coef_
# Out:
# array([[-4.39643437e-02, -7.28397453e-02,  7.81115199e-03,
#          1.43796065e+00, -2.43511827e-02, -8.82587268e-02,
#          2.18536782e-02, -3.62746059e-01,  6.03391152e-02,
#         -8.82587268e-02, -6.17259297e-02, -1.36532175e-01,
#         -1.03794594e-01, -2.92917396e-02, -5.55254063e-02,
#         -2.58439382e-02,  5.28395977e-01,  1.09090143e+00,
#          4.90652459e-03,  1.74387342e-02,  4.35486535e-01,
#          1.18651275e-01, -1.09873871e-01, -3.82034006e+01,
#         -4.55689691e-01,  6.13175595e-02,  9.81436296e-02,
#          3.07601242e-03,  1.12469847e-01, -7.60074989e-03,
#          1.44936986e-01,  8.86684673e-02, -8.08224589e-03,
#         -2.83079939e+00, -2.41646216e-01,  3.82001234e-01,
#          4.30680403e-02,  1.11404970e-01, -1.80369850e-01,
#          4.60976409e-01,  1.95362310e-03, -3.48831997e-02,
#          1.05032691e-01, -1.28022822e+00, -6.87560900e-02,
#         -4.10027368e-02, -5.48435581e-02]])

# %%
sorted(zip(horse_model.coef_[0], np.asarray(X.columns)), reverse=True)
# Out:
# [(1.4379606546808432, 'distance'),
#  (1.0909014257734675, 'place_dividend2'),
#  (0.528395977013313, 'place_dividend1'),
#  (0.4609764093826804, 'time2'),
#  (0.4354865347482661, 'win_dividend1'),
#  (0.3820012344916636, 'behind_sec2'),
#  (0.14493698616891842, 'position_sec1'),
#  (0.11865127467816888, 'horse_no'),
#  (0.11246984724459186, 'actual_weight'),
#  (0.11140496983320325, 'behind_sec4'),
#  (0.10503269101356888, 'finish_time'),
#  (0.09814362964341748, 'horse_rating'),
#  (0.08866846733904502, 'position_sec2'),
#  (0.06131755949379682, 'horse_age'),
#  (0.06033911519386868, 'sec_time4'),
#  (0.04306804031794747, 'behind_sec3'),
#  (0.021853678242001365, 'sec_time2'),
#  (0.017438734159347255, 'win_combination1'),
#  (0.007811151989020788, 'surface'),
#  (0.0049065245932247824, 'place_dividend3'),
#  (0.0030760124235132656, 'declared_weight'),
#  (0.001953623096081252, 'time3'),
#  (-0.007600749892627736, 'draw'),
#  (-0.008082245891019715, 'position_sec3'),
#  (-0.02435118267228993, 'race_class'),
#  (-0.025843938162584526, 'place_combination3'),
#  (-0.029291739571325807, 'place_combination1'),
#  (-0.03488319967131183, 'time4'),
#  (-0.04100273677758338, 'trainer_id'),
#  (-0.0439643436761882, 'race_id'),
#  (-0.0548435581018056, 'jockey_id'),
#  (-0.05552540626874486, 'place_combination2'),
#  (-0.061725929720205096, 'ldr_time2'),
#  (-0.06875608995588733, 'place_odds'),
#  (-0.07283974525804542, 'race_no'),
#  (-0.0882587267683554, 'sec_time1'),
#  (-0.0882587267683554, 'ldr_time1'),
#  (-0.10379459395758935, 'ldr_time4'),
#  (-0.10987387114775839, 'horse_id'),
#  (-0.13653217479130111, 'ldr_time3'),
#  (-0.1803698504677882, 'time1'),
#  (-0.24164621553114835, 'behind_sec1'),
#  (-0.362746059205913, 'sec_time3'),
#  (-0.4556896910861441, 'lengths_behind'),
#  (-1.2802282176170858, 'win_odds'),
#  (-2.830799393333945, 'position_sec4'),
#  (-38.203400624601535, 'result')]

# %%
X.columns
# Out:
# Index(['race_id', 'race_no', 'surface', 'distance', 'race_class', 'sec_time1',
#        'sec_time2', 'sec_time3', 'sec_time4', 'ldr_time1', 'ldr_time2',
#        'ldr_time3', 'ldr_time4', 'place_combination1', 'place_combination2',
#        'place_combination3', 'place_dividend1', 'place_dividend2',
#        'place_dividend3', 'win_combination1', 'win_dividend1', 'horse_no',
#        'horse_id', 'result', 'lengths_behind', 'horse_age', 'horse_rating',
#        'declared_weight', 'actual_weight', 'draw', 'position_sec1',
#        'position_sec2', 'position_sec3', 'position_sec4', 'behind_sec1',
#        'behind_sec2', 'behind_sec3', 'behind_sec4', 'time1', 'time2', 'time3',
#        'time4', 'finish_time', 'win_odds', 'place_odds', 'trainer_id',
#        'jockey_id'],
#       dtype='object')
