# %%
import pandas as pd
import numpy as np
from pprint import pprint
from sqlalchemy import create_engine
from keys import sqlkey

# %%
#CREATE DATABASE CONNECTION
engine = create_engine('postgresql://postgres:'+sqlkey+'@localhost:5432/horse_races')
connection = engine.connect()

# %%
training_data_df = pd.read_sql(sql='select * from training_data',con=connection)

# %%
connection.close()

# %%
training_data_df
# Out:
#        race_id  won distance  race_class  sec_time1  sec_time2  sec_time3  \
# 0            0    0     1400           5      13.53      21.59      23.94
# 1            0    0     1400           5      13.53      21.59      23.94
# 2            0    0     1400           5      13.53      21.59      23.94
# 3            0    0     1400           5      13.53      21.59      23.94
# 4            0    0     1400           5      13.53      21.59      23.94
# ...        ...  ...      ...         ...        ...        ...        ...
# 79442     6348    0     1600           2      25.46      24.06      23.73
# 79443     6348    0     1600           2      25.46      24.06      23.73
# 79444     6348    0     1600           2      25.46      24.06      23.73
# 79445     6348    0     1600           2      25.46      24.06      23.73
# 79446     6348    0     1600           2      25.46      24.06      23.73
#
#        sec_time4  ldr_time1  ldr_time2  ...  position_sec4  time1  time2  \
# 0          23.58      13.53      35.12  ...           10.0  13.85  21.59
# 1          23.58      13.53      35.12  ...            8.0  14.57  21.99
# 2          23.58      13.53      35.12  ...            7.0  13.69  21.59
# 3          23.58      13.53      35.12  ...            9.0  14.09  21.83
# 4          23.58      13.53      35.12  ...            6.0  14.77  21.75
# ...          ...        ...        ...  ...            ...    ...    ...
# 79442      22.71      25.46      49.52  ...            6.0  26.14  23.98
# 79443      22.71      25.46      49.52  ...            7.0  25.82  24.10
# 79444      22.71      25.46      49.52  ...           10.0  26.58  24.06
# 79445      22.71      25.46      49.52  ...            8.0  26.58  24.02
# 79446      22.71      25.46      49.52  ...           11.0  25.70  24.06
#
#        time3  time4  finish_time  win_odds  place_odds  trainer_id  jockey_id
# 0      23.86  24.62        83.92       9.7         3.7         118          2
# 1      23.30  23.70        83.56      16.0         4.9         164         57
# 2      23.90  24.22        83.40       3.5         1.5         137         18
# 3      23.70  24.00        83.62      39.0        11.0          80         59
# 4      23.22  23.50        83.24      50.0        14.0           9        154
# ...      ...    ...          ...       ...         ...         ...        ...
# 79442  23.53  22.52        96.17      99.0         NaN          73         40
# 79443  23.77  22.61        96.30      99.0         NaN         164         63
# 79444  23.37  22.43        96.44      99.0         NaN         111         68
# 79445  23.45  22.29        96.34       4.6         NaN         118         95
# 79446  23.77  23.10        96.63      99.0         NaN          27          4
#
# [79447 rows x 40 columns]

# %%
training_data_df = training_data_df.dropna()

# %%
training_data_df
# Out:
#        race_id  won distance  race_class  sec_time1  sec_time2  sec_time3  \
# 0            0    0     1400           5      13.53      21.59      23.94
# 1            0    0     1400           5      13.53      21.59      23.94
# 2            0    0     1400           5      13.53      21.59      23.94
# 3            0    0     1400           5      13.53      21.59      23.94
# 4            0    0     1400           5      13.53      21.59      23.94
# ...        ...  ...      ...         ...        ...        ...        ...
# 76706     6128    0     1400           3      13.34      21.79      24.09
# 76707     6128    0     1400           3      13.34      21.79      24.09
# 76708     6128    0     1400           3      13.34      21.79      24.09
# 76709     6128    0     1400           3      13.34      21.79      24.09
# 76710     6128    0     1400           3      13.34      21.79      24.09
#
#        sec_time4  ldr_time1  ldr_time2  ...  position_sec4  time1  time2  \
# 0          23.58      13.53      35.12  ...           10.0  13.85  21.59
# 1          23.58      13.53      35.12  ...            8.0  14.57  21.99
# 2          23.58      13.53      35.12  ...            7.0  13.69  21.59
# 3          23.58      13.53      35.12  ...            9.0  14.09  21.83
# 4          23.58      13.53      35.12  ...            6.0  14.77  21.75
# ...          ...        ...        ...  ...            ...    ...    ...
# 76706      22.32      13.34      35.13  ...           11.0  13.46  22.03
# 76707      22.32      13.34      35.13  ...            6.0  13.70  22.07
# 76708      22.32      13.34      35.13  ...            4.0  13.34  21.91
# 76709      22.32      13.34      35.13  ...            9.0  13.50  21.99
# 76710      22.32      13.34      35.13  ...           10.0  13.50  22.07
#
#        time3  time4  finish_time  win_odds  place_odds  trainer_id  jockey_id
# 0      23.86  24.62        83.92       9.7         3.7         118          2
# 1      23.30  23.70        83.56      16.0         4.9         164         57
# 2      23.90  24.22        83.40       3.5         1.5         137         18
# 3      23.70  24.00        83.62      39.0        11.0          80         59
# 4      23.22  23.50        83.24      50.0        14.0           9        154
# ...      ...    ...          ...       ...         ...         ...        ...
# 76706  23.97  23.41        82.87      33.0         5.7         118         40
# 76707  23.85  22.80        82.42      99.0        14.0          73        161
# 76708  24.05  22.95        82.25       8.2         2.0         138         10
# 76709  23.89  23.28        82.66      59.0         9.9           7         23
# 76710  24.21  22.96        82.74      99.0        26.0          47        162
#
# [44047 rows x 40 columns]

# %%
from sklearn.model_selection import train_test_split

X2 = training_data_df.drop(columns=["won"])

y2 = training_data_df["won"]


X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, random_state=1, stratify = y2)

# %%
X_train2.head(50)

X_train2.to_csv("X2_train.csv")
y_train2.to_csv("y2_train.csv")

X_test2.to_csv("X2_test.csv")
y_test2.to_csv("y2_test.csv")

# %%
from sklearn import preprocessing 
scaler = preprocessing.MinMaxScaler()
minmax_df2 = scaler.fit(X_train2) #something wrong here possibly
X_train_scaled2 = scaler.transform(X_train2)
X_test_scaled2 = scaler.transform(X_test2)

# %%
from sklearn.linear_model import LogisticRegression
horse_model2 = LogisticRegression(max_iter=1000)
horse_model2
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
horse_model2.fit(X_train_scaled2, y_train2)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(f"Training Data Score: {horse_model2.score(X_train_scaled2, y_train2)}")
print(f"Testing Data Score: {horse_model2.score(X_test_scaled2, y_test2)}")
print(f"for one single line:{horse_model2.predict(X_train_scaled2[17].reshape(1,-1))}")
# Out:
# Training Data Score: 0.9482367186317542
# Testing Data Score: 0.9502361060661098
# for one single line:[0]

# %%
horse_model2.coef_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3867b0e30da7> in <module>
# ----> 1 horse_model2.coef_
#
# NameError: name 'horse_model2' is not defined

# %%
i = 0
while i < 1000:
    print(f"{i}for one single line:{horse_model2.predict(X_train_scaled2[i].reshape(1,-1))}")
    i+=1
# Out:
# 0for one single line:[0]
# 1for one single line:[0]
# 2for one single line:[0]
# 3for one single line:[0]
# 4for one single line:[0]
# 5for one single line:[0]
# 6for one single line:[0]
# 7for one single line:[0]
# 8for one single line:[0]
# 9for one single line:[0]
# 10for one single line:[0]
# 11for one single line:[0]
# 12for one single line:[0]
# 13for one single line:[0]
# 14for one single line:[0]
# 15for one single line:[0]
# 16for one single line:[0]
# 17for one single line:[0]
# 18for one single line:[0]
# 19for one single line:[0]
# 20for one single line:[0]
# 21for one single line:[0]
# 22for one single line:[0]
# 23for one single line:[0]
# 24for one single line:[0]
# 25for one single line:[0]
# 26for one single line:[0]
# 27for one single line:[0]
# 28for one single line:[0]
# 29for one single line:[0]
# 30for one single line:[0]
# 31for one single line:[0]
# 32for one single line:[0]
# 33for one single line:[0]
# 34for one single line:[1]
# 35for one single line:[1]
# 36for one single line:[0]
# 37for one single line:[0]
# 38for one single line:[0]
# 39for one single line:[0]
# 40for one single line:[0]
# 41for one single line:[0]
# 42for one single line:[0]
# 43for one single line:[0]
# 44for one single line:[0]
# 45for one single line:[0]
# 46for one single line:[0]
# 47for one single line:[0]
# 48for one single line:[1]
# 49for one single line:[0]
# 50for one single line:[0]
# 51for one single line:[0]
# 52for one single line:[0]
# 53for one single line:[0]
# 54for one single line:[0]
# 55for one single line:[1]
# 56for one single line:[0]
# 57for one single line:[0]
# 58for one single line:[0]
# 59for one single line:[0]
# 60for one single line:[0]
# 61for one single line:[0]
# 62for one single line:[0]
# 63for one single line:[0]
# 64for one single line:[0]
# 65for one single line:[0]
# 66for one single line:[0]
# 67for one single line:[0]
# 68for one single line:[0]
# 69for one single line:[0]
# 70for one single line:[0]
# 71for one single line:[0]
# 72for one single line:[0]
# 73for one single line:[0]
# 74for one single line:[0]
# 75for one single line:[0]
# 76for one single line:[1]
# 77for one single line:[0]
# 78for one single line:[0]
# 79for one single line:[0]
# 80for one single line:[0]
# 81for one single line:[0]
# 82for one single line:[0]
# 83for one single line:[0]
# 84for one single line:[0]
# 85for one single line:[0]
# 86for one single line:[0]
# 87for one single line:[0]
# 88for one single line:[0]
# 89for one single line:[0]
# 90for one single line:[0]
# 91for one single line:[0]
# 92for one single line:[0]
# 93for one single line:[0]
# 94for one single line:[0]
# 95for one single line:[0]
# 96for one single line:[1]
# 97for one single line:[0]
# 98for one single line:[0]
# 99for one single line:[1]
# 100for one single line:[0]
# 101for one single line:[0]
# 102for one single line:[0]
# 103for one single line:[0]
# 104for one single line:[0]
# 105for one single line:[0]
# 106for one single line:[0]
# 107for one single line:[0]
# 108for one single line:[0]
# 109for one single line:[0]
# 110for one single line:[0]
# 111for one single line:[0]
# 112for one single line:[0]
# 113for one single line:[0]
# 114for one single line:[0]
# 115for one single line:[0]
# 116for one single line:[0]
# 117for one single line:[0]
# 118for one single line:[1]
# 119for one single line:[0]
# 120for one single line:[0]
# 121for one single line:[0]
# 122for one single line:[0]
# 123for one single line:[0]
# 124for one single line:[0]
# 125for one single line:[0]
# 126for one single line:[1]
# 127for one single line:[0]
# 128for one single line:[0]
# 129for one single line:[0]
# 130for one single line:[0]
# 131for one single line:[0]
# 132for one single line:[0]
# 133for one single line:[0]
# 134for one single line:[0]
# 135for one single line:[0]
# 136for one single line:[0]
# 137for one single line:[0]
# 138for one single line:[0]
# 139for one single line:[0]
# 140for one single line:[0]
# 141for one single line:[0]
# 142for one single line:[0]
# 143for one single line:[0]
# 144for one single line:[0]
# 145for one single line:[0]
# 146for one single line:[0]
# 147for one single line:[0]
# 148for one single line:[0]
# 149for one single line:[0]
# 150for one single line:[0]
# 151for one single line:[0]
# 152for one single line:[0]
# 153for one single line:[0]
# 154for one single line:[0]
# 155for one single line:[0]
# 156for one single line:[0]
# 157for one single line:[0]
# 158for one single line:[0]
# 159for one single line:[0]
# 160for one single line:[0]
# 161for one single line:[0]
# 162for one single line:[0]
# 163for one single line:[0]
# 164for one single line:[0]
# 165for one single line:[0]
# 166for one single line:[0]
# 167for one single line:[0]
# 168for one single line:[0]
# 169for one single line:[0]
# 170for one single line:[0]
# 171for one single line:[0]
# 172for one single line:[0]
# 173for one single line:[0]
# 174for one single line:[0]
# 175for one single line:[0]
# 176for one single line:[1]
# 177for one single line:[0]
# 178for one single line:[0]
# 179for one single line:[0]
# 180for one single line:[0]
# 181for one single line:[0]
# 182for one single line:[1]
# 183for one single line:[0]
# 184for one single line:[1]
# 185for one single line:[0]
# 186for one single line:[0]
# 187for one single line:[0]
# 188for one single line:[0]
# 189for one single line:[0]
# 190for one single line:[0]
# 191for one single line:[0]
# 192for one single line:[0]
# 193for one single line:[0]
# 194for one single line:[0]
# 195for one single line:[0]
# 196for one single line:[0]
# 197for one single line:[0]
# 198for one single line:[0]
# 199for one single line:[0]
# 200for one single line:[0]
# 201for one single line:[0]
# 202for one single line:[1]
# 203for one single line:[0]
# 204for one single line:[0]
# 205for one single line:[0]
# 206for one single line:[0]
# 207for one single line:[1]
# 208for one single line:[0]
# 209for one single line:[0]
# 210for one single line:[0]
# 211for one single line:[0]
# 212for one single line:[0]
# 213for one single line:[0]
# 214for one single line:[0]
# 215for one single line:[0]
# 216for one single line:[0]
# 217for one single line:[0]
# 218for one single line:[0]
# 219for one single line:[0]
# 220for one single line:[0]
# 221for one single line:[0]
# 222for one single line:[0]
# 223for one single line:[0]
# 224for one single line:[0]
# 225for one single line:[0]
# 226for one single line:[0]
# 227for one single line:[0]
# 228for one single line:[0]
# 229for one single line:[0]
# 230for one single line:[0]
# 231for one single line:[0]
# 232for one single line:[0]
# 233for one single line:[0]
# 234for one single line:[0]
# 235for one single line:[0]
# 236for one single line:[0]
# 237for one single line:[0]
# 238for one single line:[0]
# 239for one single line:[0]
# 240for one single line:[0]
# 241for one single line:[0]
# 242for one single line:[0]
# 243for one single line:[0]
# 244for one single line:[0]
# 245for one single line:[0]
# 246for one single line:[0]
# 247for one single line:[0]
# 248for one single line:[0]
# 249for one single line:[1]
# 250for one single line:[0]
# 251for one single line:[0]
# 252for one single line:[0]
# 253for one single line:[0]
# 254for one single line:[0]
# 255for one single line:[0]
# 256for one single line:[0]
# 257for one single line:[0]
# 258for one single line:[0]
# 259for one single line:[0]
# 260for one single line:[0]
# 261for one single line:[0]
# 262for one single line:[0]
# 263for one single line:[0]
# 264for one single line:[0]
# 265for one single line:[0]
# 266for one single line:[0]
# 267for one single line:[0]
# 268for one single line:[0]
# 269for one single line:[0]
# 270for one single line:[0]
# 271for one single line:[0]
# 272for one single line:[0]
# 273for one single line:[0]
# 274for one single line:[0]
# 275for one single line:[0]
# 276for one single line:[1]
# 277for one single line:[0]
# 278for one single line:[0]
# 279for one single line:[0]
# 280for one single line:[0]
# 281for one single line:[0]
# 282for one single line:[0]
# 283for one single line:[0]
# 284for one single line:[0]
# 285for one single line:[0]
# 286for one single line:[0]
# 287for one single line:[0]
# 288for one single line:[0]
# 289for one single line:[0]
# 290for one single line:[0]
# 291for one single line:[0]
# 292for one single line:[0]
# 293for one single line:[0]
# 294for one single line:[0]
# 295for one single line:[0]
# 296for one single line:[0]
# 297for one single line:[0]
# 298for one single line:[0]
# 299for one single line:[1]
# 300for one single line:[0]
# 301for one single line:[0]
# 302for one single line:[0]
# 303for one single line:[0]
# 304for one single line:[0]
# 305for one single line:[0]
# 306for one single line:[0]
# 307for one single line:[0]
# 308for one single line:[0]
# 309for one single line:[0]
# 310for one single line:[0]
# 311for one single line:[0]
# 312for one single line:[0]
# 313for one single line:[0]
# 314for one single line:[0]
# 315for one single line:[0]
# 316for one single line:[0]
# 317for one single line:[0]
# 318for one single line:[0]
# 319for one single line:[0]
# 320for one single line:[0]
# 321for one single line:[0]
# 322for one single line:[0]
# 323for one single line:[0]
# 324for one single line:[0]
# 325for one single line:[0]
# 326for one single line:[0]
# 327for one single line:[0]
# 328for one single line:[0]
# 329for one single line:[0]
# 330for one single line:[0]
# 331for one single line:[0]
# 332for one single line:[0]
# 333for one single line:[1]
# 334for one single line:[0]
# 335for one single line:[0]
# 336for one single line:[0]
# 337for one single line:[0]
# 338for one single line:[1]
# 339for one single line:[0]
# 340for one single line:[0]
# 341for one single line:[0]
# 342for one single line:[0]
# 343for one single line:[0]
# 344for one single line:[0]
# 345for one single line:[0]
# 346for one single line:[0]
# 347for one single line:[0]
# 348for one single line:[0]
# 349for one single line:[0]
# 350for one single line:[0]
# 351for one single line:[0]
# 352for one single line:[0]
# 353for one single line:[0]
# 354for one single line:[0]
# 355for one single line:[0]
# 356for one single line:[0]
# 357for one single line:[0]
# 358for one single line:[0]
# 359for one single line:[0]
# 360for one single line:[0]
# 361for one single line:[0]
# 362for one single line:[0]
# 363for one single line:[0]
# 364for one single line:[0]
# 365for one single line:[0]
# 366for one single line:[0]
# 367for one single line:[0]
# 368for one single line:[0]
# 369for one single line:[0]
# 370for one single line:[0]
# 371for one single line:[0]
# 372for one single line:[0]
# 373for one single line:[0]
# 374for one single line:[0]
# 375for one single line:[0]
# 376for one single line:[0]
# 377for one single line:[0]
# 378for one single line:[0]
# 379for one single line:[0]
# 380for one single line:[1]
# 381for one single line:[0]
# 382for one single line:[0]
# 383for one single line:[0]
# 384for one single line:[0]
# 385for one single line:[0]
# 386for one single line:[0]
# 387for one single line:[0]
# 388for one single line:[0]
# 389for one single line:[0]
# 390for one single line:[0]
# 391for one single line:[0]
# 392for one single line:[0]
# 393for one single line:[0]
# 394for one single line:[0]
# 395for one single line:[0]
# 396for one single line:[0]
# 397for one single line:[0]
# 398for one single line:[0]
# 399for one single line:[0]
# 400for one single line:[0]
# 401for one single line:[0]
# 402for one single line:[0]
# 403for one single line:[0]
# 404for one single line:[0]
# 405for one single line:[0]
# 406for one single line:[0]
# 407for one single line:[0]
# 408for one single line:[0]
# 409for one single line:[0]
# 410for one single line:[0]
# 411for one single line:[0]
# 412for one single line:[0]
# 413for one single line:[0]
# 414for one single line:[0]
# 415for one single line:[0]
# 416for one single line:[0]
# 417for one single line:[0]
# 418for one single line:[0]
# 419for one single line:[0]
# 420for one single line:[0]
# 421for one single line:[0]
# 422for one single line:[0]
# 423for one single line:[0]
# 424for one single line:[0]
# 425for one single line:[0]
# 426for one single line:[0]
# 427for one single line:[0]
# 428for one single line:[0]
# 429for one single line:[0]
# 430for one single line:[0]
# 431for one single line:[0]
# 432for one single line:[0]
# 433for one single line:[0]
# 434for one single line:[0]
# 435for one single line:[0]
# 436for one single line:[0]
# 437for one single line:[0]
# 438for one single line:[0]
# 439for one single line:[0]
# 440for one single line:[0]
# 441for one single line:[0]
# 442for one single line:[0]
# 443for one single line:[0]
# 444for one single line:[0]
# 445for one single line:[0]
# 446for one single line:[0]
# 447for one single line:[0]
# 448for one single line:[0]
# 449for one single line:[0]
# 450for one single line:[0]
# 451for one single line:[0]
# 452for one single line:[0]
# 453for one single line:[0]
# 454for one single line:[0]
# 455for one single line:[0]
# 456for one single line:[0]
# 457for one single line:[0]
# 458for one single line:[1]
# 459for one single line:[0]
# 460for one single line:[0]
# 461for one single line:[0]
# 462for one single line:[0]
# 463for one single line:[0]
# 464for one single line:[0]
# 465for one single line:[0]
# 466for one single line:[0]
# 467for one single line:[0]
# 468for one single line:[0]
# 469for one single line:[0]
# 470for one single line:[0]
# 471for one single line:[0]
# 472for one single line:[0]
# 473for one single line:[0]
# 474for one single line:[0]
# 475for one single line:[0]
# 476for one single line:[0]
# 477for one single line:[0]
# 478for one single line:[0]
# 479for one single line:[0]
# 480for one single line:[0]
# 481for one single line:[0]
# 482for one single line:[0]
# 483for one single line:[1]
# 484for one single line:[0]
# 485for one single line:[0]
# 486for one single line:[0]
# 487for one single line:[0]
# 488for one single line:[0]
# 489for one single line:[1]
# 490for one single line:[0]
# 491for one single line:[0]
# 492for one single line:[0]
# 493for one single line:[1]
# 494for one single line:[0]
# 495for one single line:[0]
# 496for one single line:[0]
# 497for one single line:[0]
# 498for one single line:[0]
# 499for one single line:[0]
# 500for one single line:[0]
# 501for one single line:[0]
# 502for one single line:[0]
# 503for one single line:[0]
# 504for one single line:[0]
# 505for one single line:[0]
# 506for one single line:[0]
# 507for one single line:[0]
# 508for one single line:[0]
# 509for one single line:[0]
# 510for one single line:[0]
# 511for one single line:[0]
# 512for one single line:[0]
# 513for one single line:[0]
# 514for one single line:[0]
# 515for one single line:[0]
# 516for one single line:[0]
# 517for one single line:[0]
# 518for one single line:[0]
# 519for one single line:[0]
# 520for one single line:[0]
# 521for one single line:[0]
# 522for one single line:[0]
# 523for one single line:[0]
# 524for one single line:[0]
# 525for one single line:[0]
# 526for one single line:[0]
# 527for one single line:[0]
# 528for one single line:[0]
# 529for one single line:[0]
# 530for one single line:[0]
# 531for one single line:[0]
# 532for one single line:[0]
# 533for one single line:[0]
# 534for one single line:[0]
# 535for one single line:[0]
# 536for one single line:[0]
# 537for one single line:[0]
# 538for one single line:[0]
# 539for one single line:[0]
# 540for one single line:[0]
# 541for one single line:[0]
# 542for one single line:[0]
# 543for one single line:[0]
# 544for one single line:[0]
# 545for one single line:[0]
# 546for one single line:[0]
# 547for one single line:[0]
# 548for one single line:[0]
# 549for one single line:[0]
# 550for one single line:[0]
# 551for one single line:[0]
# 552for one single line:[0]
# 553for one single line:[0]
# 554for one single line:[0]
# 555for one single line:[0]
# 556for one single line:[0]
# 557for one single line:[0]
# 558for one single line:[0]
# 559for one single line:[0]
# 560for one single line:[0]
# 561for one single line:[0]
# 562for one single line:[0]
# 563for one single line:[0]
# 564for one single line:[0]
# 565for one single line:[0]
# 566for one single line:[0]
# 567for one single line:[0]
# 568for one single line:[0]
# 569for one single line:[0]
# 570for one single line:[0]
# 571for one single line:[0]
# 572for one single line:[0]
# 573for one single line:[0]
# 574for one single line:[0]
# 575for one single line:[0]
# 576for one single line:[0]
# 577for one single line:[0]
# 578for one single line:[0]
# 579for one single line:[0]
# 580for one single line:[0]
# 581for one single line:[0]
# 582for one single line:[0]
# 583for one single line:[0]
# 584for one single line:[0]
# 585for one single line:[0]
# 586for one single line:[0]
# 587for one single line:[0]
# 588for one single line:[0]
# 589for one single line:[0]
# 590for one single line:[0]
# 591for one single line:[0]
# 592for one single line:[0]
# 593for one single line:[0]
# 594for one single line:[0]
# 595for one single line:[0]
# 596for one single line:[0]
# 597for one single line:[0]
# 598for one single line:[1]
# 599for one single line:[0]
# 600for one single line:[0]
# 601for one single line:[0]
# 602for one single line:[0]
# 603for one single line:[0]
# 604for one single line:[0]
# 605for one single line:[0]
# 606for one single line:[0]
# 607for one single line:[0]
# 608for one single line:[0]
# 609for one single line:[0]
# 610for one single line:[0]
# 611for one single line:[0]
# 612for one single line:[0]
# 613for one single line:[0]
# 614for one single line:[0]
# 615for one single line:[0]
# 616for one single line:[0]
# 617for one single line:[0]
# 618for one single line:[0]
# 619for one single line:[0]
# 620for one single line:[0]
# 621for one single line:[0]
# 622for one single line:[0]
# 623for one single line:[0]
# 624for one single line:[0]
# 625for one single line:[0]
# 626for one single line:[1]
# 627for one single line:[0]
# 628for one single line:[0]
# 629for one single line:[0]
# 630for one single line:[0]
# 631for one single line:[0]
# 632for one single line:[0]
# 633for one single line:[0]
# 634for one single line:[0]
# 635for one single line:[0]
# 636for one single line:[0]
# 637for one single line:[0]
# 638for one single line:[0]
# 639for one single line:[0]
# 640for one single line:[0]
# 641for one single line:[0]
# 642for one single line:[0]
# 643for one single line:[0]
# 644for one single line:[0]
# 645for one single line:[0]
# 646for one single line:[0]
# 647for one single line:[0]
# 648for one single line:[1]
# 649for one single line:[0]
# 650for one single line:[0]
# 651for one single line:[0]
# 652for one single line:[0]
# 653for one single line:[0]
# 654for one single line:[0]
# 655for one single line:[0]
# 656for one single line:[0]
# 657for one single line:[0]
# 658for one single line:[0]
# 659for one single line:[0]
# 660for one single line:[0]
# 661for one single line:[0]
# 662for one single line:[0]
# 663for one single line:[0]
# 664for one single line:[0]
# 665for one single line:[0]
# 666for one single line:[1]
# 667for one single line:[0]
# 668for one single line:[0]
# 669for one single line:[0]
# 670for one single line:[0]
# 671for one single line:[0]
# 672for one single line:[0]
# 673for one single line:[0]
# 674for one single line:[0]
# 675for one single line:[0]
# 676for one single line:[1]
# 677for one single line:[0]
# 678for one single line:[0]
# 679for one single line:[0]
# 680for one single line:[0]
# 681for one single line:[0]
# 682for one single line:[0]
# 683for one single line:[0]
# 684for one single line:[0]
# 685for one single line:[0]
# 686for one single line:[0]
# 687for one single line:[0]
# 688for one single line:[0]
# 689for one single line:[0]
# 690for one single line:[0]
# 691for one single line:[0]
# 692for one single line:[0]
# 693for one single line:[0]
# 694for one single line:[0]
# 695for one single line:[0]
# 696for one single line:[0]
# 697for one single line:[0]
# 698for one single line:[0]
# 699for one single line:[0]
# 700for one single line:[0]
# 701for one single line:[0]
# 702for one single line:[0]
# 703for one single line:[0]
# 704for one single line:[0]
# 705for one single line:[0]
# 706for one single line:[0]
# 707for one single line:[0]
# 708for one single line:[0]
# 709for one single line:[0]
# 710for one single line:[0]
# 711for one single line:[0]
# 712for one single line:[0]
# 713for one single line:[0]
# 714for one single line:[0]
# 715for one single line:[0]
# 716for one single line:[0]
# 717for one single line:[0]
# 718for one single line:[0]
# 719for one single line:[0]
# 720for one single line:[0]
# 721for one single line:[0]
# 722for one single line:[0]
# 723for one single line:[0]
# 724for one single line:[0]
# 725for one single line:[0]
# 726for one single line:[0]
# 727for one single line:[0]
# 728for one single line:[0]
# 729for one single line:[0]
# 730for one single line:[0]
# 731for one single line:[0]
# 732for one single line:[0]
# 733for one single line:[0]
# 734for one single line:[0]
# 735for one single line:[0]
# 736for one single line:[0]
# 737for one single line:[0]
# 738for one single line:[1]
# 739for one single line:[0]
# 740for one single line:[0]
# 741for one single line:[0]
# 742for one single line:[0]
# 743for one single line:[0]
# 744for one single line:[0]
# 745for one single line:[0]
# 746for one single line:[0]
# 747for one single line:[0]
# 748for one single line:[0]
# 749for one single line:[0]
# 750for one single line:[0]
# 751for one single line:[0]
# 752for one single line:[0]
# 753for one single line:[0]
# 754for one single line:[0]
# 755for one single line:[0]
# 756for one single line:[0]
# 757for one single line:[0]
# 758for one single line:[0]
# 759for one single line:[0]
# 760for one single line:[0]
# 761for one single line:[0]
# 762for one single line:[0]
# 763for one single line:[0]
# 764for one single line:[0]
# 765for one single line:[0]
# 766for one single line:[0]
# 767for one single line:[0]
# 768for one single line:[0]
# 769for one single line:[1]
# 770for one single line:[0]
# 771for one single line:[0]
# 772for one single line:[0]
# 773for one single line:[0]
# 774for one single line:[0]
# 775for one single line:[0]
# 776for one single line:[0]
# 777for one single line:[0]
# 778for one single line:[0]
# 779for one single line:[0]
# 780for one single line:[0]
# 781for one single line:[0]
# 782for one single line:[0]
# 783for one single line:[0]
# 784for one single line:[0]
# 785for one single line:[0]
# 786for one single line:[0]
# 787for one single line:[0]
# 788for one single line:[0]
# 789for one single line:[0]
# 790for one single line:[0]
# 791for one single line:[0]
# 792for one single line:[0]
# 793for one single line:[0]
# 794for one single line:[1]
# 795for one single line:[0]
# 796for one single line:[0]
# 797for one single line:[0]
# 798for one single line:[1]
# 799for one single line:[0]
# 800for one single line:[0]
# 801for one single line:[0]
# 802for one single line:[0]
# 803for one single line:[0]
# 804for one single line:[0]
# 805for one single line:[0]
# 806for one single line:[1]
# 807for one single line:[0]
# 808for one single line:[0]
# 809for one single line:[0]
# 810for one single line:[0]
# 811for one single line:[0]
# 812for one single line:[0]
# 813for one single line:[0]
# 814for one single line:[0]
# 815for one single line:[0]
# 816for one single line:[0]
# 817for one single line:[0]
# 818for one single line:[0]
# 819for one single line:[0]
# 820for one single line:[0]
# 821for one single line:[0]
# 822for one single line:[0]
# 823for one single line:[0]
# 824for one single line:[0]
# 825for one single line:[0]
# 826for one single line:[0]
# 827for one single line:[0]
# 828for one single line:[0]
# 829for one single line:[0]
# 830for one single line:[0]
# 831for one single line:[0]
# 832for one single line:[0]
# 833for one single line:[0]
# 834for one single line:[0]
# 835for one single line:[0]
# 836for one single line:[0]
# 837for one single line:[0]
# 838for one single line:[0]
# 839for one single line:[0]
# 840for one single line:[0]
# 841for one single line:[0]
# 842for one single line:[0]
# 843for one single line:[0]
# 844for one single line:[0]
# 845for one single line:[0]
# 846for one single line:[0]
# 847for one single line:[0]
# 848for one single line:[0]
# 849for one single line:[0]
# 850for one single line:[0]
# 851for one single line:[0]
# 852for one single line:[0]
# 853for one single line:[0]
# 854for one single line:[0]
# 855for one single line:[0]
# 856for one single line:[0]
# 857for one single line:[0]
# 858for one single line:[0]
# 859for one single line:[0]
# 860for one single line:[0]
# 861for one single line:[0]
# 862for one single line:[0]
# 863for one single line:[0]
# 864for one single line:[0]
# 865for one single line:[0]
# 866for one single line:[0]
# 867for one single line:[0]
# 868for one single line:[0]
# 869for one single line:[0]
# 870for one single line:[0]
# 871for one single line:[0]
# 872for one single line:[0]
# 873for one single line:[1]
# 874for one single line:[0]
# 875for one single line:[0]
# 876for one single line:[0]
# 877for one single line:[0]
# 878for one single line:[0]
# 879for one single line:[0]
# 880for one single line:[0]
# 881for one single line:[0]
# 882for one single line:[0]
# 883for one single line:[1]
# 884for one single line:[0]
# 885for one single line:[0]
# 886for one single line:[0]
# 887for one single line:[0]
# 888for one single line:[0]
# 889for one single line:[0]
# 890for one single line:[0]
# 891for one single line:[0]
# 892for one single line:[0]
# 893for one single line:[0]
# 894for one single line:[0]
# 895for one single line:[0]
# 896for one single line:[0]
# 897for one single line:[0]
# 898for one single line:[0]
# 899for one single line:[0]
# 900for one single line:[0]
# 901for one single line:[0]
# 902for one single line:[0]
# 903for one single line:[0]
# 904for one single line:[1]
# 905for one single line:[0]
# 906for one single line:[1]
# 907for one single line:[0]
# 908for one single line:[0]
# 909for one single line:[0]
# 910for one single line:[0]
# 911for one single line:[0]
# 912for one single line:[0]
# 913for one single line:[0]
# 914for one single line:[0]
# 915for one single line:[0]
# 916for one single line:[0]
# 917for one single line:[0]
# 918for one single line:[1]
# 919for one single line:[0]
# 920for one single line:[0]
# 921for one single line:[0]
# 922for one single line:[0]
# 923for one single line:[0]
# 924for one single line:[0]
# 925for one single line:[0]
# 926for one single line:[0]
# 927for one single line:[1]
# 928for one single line:[0]
# 929for one single line:[0]
# 930for one single line:[0]
# 931for one single line:[0]
# 932for one single line:[0]
# 933for one single line:[0]
# 934for one single line:[0]
# 935for one single line:[0]
# 936for one single line:[0]
# 937for one single line:[0]
# 938for one single line:[0]
# 939for one single line:[0]
# 940for one single line:[0]
# 941for one single line:[0]
# 942for one single line:[0]
# 943for one single line:[0]
# 944for one single line:[0]
# 945for one single line:[0]
# 946for one single line:[0]
# 947for one single line:[0]
# 948for one single line:[0]
# 949for one single line:[0]
# 950for one single line:[0]
# 951for one single line:[0]
# 952for one single line:[0]
# 953for one single line:[0]
# 954for one single line:[0]
# 955for one single line:[0]
# 956for one single line:[0]
# 957for one single line:[0]
# 958for one single line:[0]
# 959for one single line:[0]
# 960for one single line:[0]
# 961for one single line:[0]
# 962for one single line:[0]
# 963for one single line:[0]
# 964for one single line:[0]
# 965for one single line:[0]
# 966for one single line:[0]
# 967for one single line:[0]
# 968for one single line:[0]
# 969for one single line:[0]
# 970for one single line:[0]
# 971for one single line:[0]
# 972for one single line:[0]
# 973for one single line:[0]
# 974for one single line:[0]
# 975for one single line:[0]
# 976for one single line:[0]
# 977for one single line:[0]
# 978for one single line:[0]
# 979for one single line:[1]
# 980for one single line:[0]
# 981for one single line:[0]
# 982for one single line:[0]
# 983for one single line:[0]
# 984for one single line:[0]
# 985for one single line:[0]
# 986for one single line:[0]
# 987for one single line:[0]
# 988for one single line:[0]
# 989for one single line:[0]
# 990for one single line:[0]
# 991for one single line:[0]
# 992for one single line:[0]
# 993for one single line:[1]
# 994for one single line:[0]
# 995for one single line:[0]
# 996for one single line:[0]
# 997for one single line:[0]
# 998for one single line:[0]
# 999for one single line:[0]
